# %% [markdown]
# ## NHS Post processing Library

# %% [markdown]
# This notebook provides examples on how to carry out data evaluation, visualization and analysis using the post_processing python library. Be sure to go through the [Quick Start](https://nhs-postprocessing.readthedocs.io/en/latest/QuickStart.html) section of the [documentation](https://nhs-postprocessing.readthedocs.io/en/latest/index.html) for instructions on how to access and import the libary and its packages.

# %% [markdown]
# ##### Note:
# The Library is still under active development and empty sections will be completed in Due time

# %% [markdown]
# ### Table of content
# - Requirements
# - Data Manipulation(generating and obtaining the Dataframes required)
# - Analysis
# - Viaualizations

# %% [markdown]
# ##### All files are available in the docs/source/notebooks folder where the notebook is located

# %% [markdown]
# ### Requirements
#
# The conda environmnent contains all libraries associated the post processing library. After setting up the conda environment, you only have to import the metrics and visualization modules from postprocessinglib.evaluation

# %%
### Remove and modify these later.
import sys
import pandas as pd
sys.path.append("../../../")

# %%
from postprocessinglib.evaluation import data, metrics, visuals
from postprocessinglib.utilities import helper_functions as hlp

# %% [markdown]
# From this point on, the function you use will depend on which project you are working on and what sort of data i.e., the datatype of the data, you have.

# %% [markdown]
# ### DATA MANIPULATION

# %% [markdown]
# ### MESH CSV files

# %% [markdown]
# Assuming you have a csv file containing an csv file with observed and simulated values for a list of stations of the form:
# | Some datetime  | station1_obs | station1_sim | station2_obs | station2_sim |
# | -------------- | ------------ | ------------ | ------------ | ------------ |
#
# We simply pass it into our generate dataframes function as shown below:

# %%
# passing a controlled csv file for testing
path = "MESH_output_streamflow_1.csv"

# assuming the simulation model needs 365 days to warm up and account for erros during the learning phase.
DATAFRAMES = data.generate_dataframes(csv_fpath=path, warm_up=365)

# %% [markdown]
# In this case, because we dont pass in aggregation parameters, we end up with the three default dataframnes in our dictionary; the merged dataframe, the observed data and the simulated data

# %%
print("The Merged dataframe: \n")
print(DATAFRAMES["DF"])
print("The Observed dataframe: \n")
print(DATAFRAMES["DF_OBSERVED"])
print("\nThe Simulated dataframe: \n")
print(DATAFRAMES["DF_SIMULATED"])
# Out:
# The Merged dataframe:
#
#             QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1980-12-31           10.20       2.530770             NaN       1.006860
# 1981-01-01            9.85       2.518999             NaN       1.001954
# 1981-01-02           10.20       2.507289             NaN       0.997078
# 1981-01-03           10.00       2.495637             NaN       0.992233
# 1981-01-04           10.10       2.484073             NaN       0.987417
# ...                    ...            ...             ...            ...
# 2017-12-27             NaN       4.418050             NaN       1.380227
# 2017-12-28             NaN       4.393084             NaN       1.372171
# 2017-12-29             NaN       4.368303             NaN       1.364174
# 2017-12-30             NaN       4.343699             NaN       1.356237
# 2017-12-31             NaN       4.319275             NaN       1.348359
#
# [13515 rows x 4 columns]
# The Observed dataframe:
#
#             QOMEAS_05BB001  QOMEAS_05BA001
# 1980-12-31           10.20             NaN
# 1981-01-01            9.85             NaN
# 1981-01-02           10.20             NaN
# 1981-01-03           10.00             NaN
# 1981-01-04           10.10             NaN
# ...                    ...             ...
# 2017-12-27             NaN             NaN
# 2017-12-28             NaN             NaN
# 2017-12-29             NaN             NaN
# 2017-12-30             NaN             NaN
# 2017-12-31             NaN             NaN
#
# [13515 rows x 2 columns]
#
# The Simulated dataframe:
#
#             QOSIM_05BB001  QOSIM_05BA001
# 1980-12-31       2.530770       1.006860
# 1981-01-01       2.518999       1.001954
# 1981-01-02       2.507289       0.997078
# 1981-01-03       2.495637       0.992233
# 1981-01-04       2.484073       0.987417
# ...                   ...            ...
# 2017-12-27       4.418050       1.380227
# 2017-12-28       4.393084       1.372171
# 2017-12-29       4.368303       1.364174
# 2017-12-30       4.343699       1.356237
# 2017-12-31       4.319275       1.348359
#
# [13515 rows x 2 columns]

# %% [markdown]
# The Simulated and Observed dataframes are particularly important in the calculation of our metrics

# %%
# You are also  able to generate the dataframes for a given period of time i.e from a start date, till an end date
# and everything in between
DATAFRAMES_January2010 = data.generate_dataframes(csv_fpath=path, warm_up=365, start_date='2010-01-01' , end_date='2010-1-31')
DATAFRAMES_till2009 = data.generate_dataframes(csv_fpath=path, warm_up=365, end_date='2009-12-31')
DATAFRAMES_from1995 = data.generate_dataframes(csv_fpath=path, warm_up=365, start_date='1995-01-01')

# %%
print("The Merged dataframe for January 2010: \n")
print(DATAFRAMES_January2010["DF"])
print("The Observed dataframe for January 2010: \n")
print(DATAFRAMES_January2010["DF_OBSERVED"])
print("\nThe Simulated dataframe for January 2010: \n")
print(DATAFRAMES_January2010["DF_OBSERVED"])
# Out:
# The Merged dataframe for January 2010:
#
#             QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 2010-01-01             NaN       4.000698             NaN       0.793435
# 2010-01-02             NaN       3.978494             NaN       0.789141
# 2010-01-03             NaN       3.956450             NaN       0.784877
# 2010-01-04             NaN       3.934558             NaN       0.780643
# 2010-01-05             NaN       3.912824             NaN       0.776437
# 2010-01-06             NaN       3.891242             NaN       0.772261
# 2010-01-07             NaN       3.869810             NaN       0.768114
# 2010-01-08             NaN       3.848532             NaN       0.763995
# 2010-01-09             NaN       3.827400             NaN       0.759905
# 2010-01-10             NaN       3.806418             NaN       0.755842
# 2010-01-11             NaN       3.785582             NaN       0.751808
# 2010-01-12             NaN       3.764892             NaN       0.747801
# 2010-01-13             NaN       3.744347             NaN       0.743821
# 2010-01-14             NaN       3.723943             NaN       0.739868
# 2010-01-15             NaN       3.703679             NaN       0.735942
# 2010-01-16             NaN       3.683560             NaN       0.732043
# 2010-01-17             NaN       3.663576             NaN       0.728171
# 2010-01-18             NaN       3.643738             NaN       0.724324
# 2010-01-19             NaN       3.624028             NaN       0.720504
# 2010-01-20             NaN       3.604458             NaN       0.716710
# 2010-01-21             NaN       3.585024             NaN       0.712941
# 2010-01-22             NaN       3.565720             NaN       0.709197
# 2010-01-23             NaN       3.546552             NaN       0.705479
# 2010-01-24             NaN       3.527510             NaN       0.701786
# 2010-01-25             NaN       3.508604             NaN       0.698118
# 2010-01-26             NaN       3.489822             NaN       0.694474
# 2010-01-27             NaN       3.471175             NaN       0.690854
# 2010-01-28             NaN       3.452648             NaN       0.687258
# 2010-01-29             NaN       3.434252             NaN       0.683687
# 2010-01-30             NaN       3.415977             NaN       0.680139
# 2010-01-31             NaN       3.397829             NaN       0.676615
# The Observed dataframe for January 2010:
#
#             QOMEAS_05BB001  QOMEAS_05BA001
# 2010-01-01             NaN             NaN
# 2010-01-02             NaN             NaN
# 2010-01-03             NaN             NaN
# 2010-01-04             NaN             NaN
# 2010-01-05             NaN             NaN
# 2010-01-06             NaN             NaN
# 2010-01-07             NaN             NaN
# 2010-01-08             NaN             NaN
# 2010-01-09             NaN             NaN
# 2010-01-10             NaN             NaN
# 2010-01-11             NaN             NaN
# 2010-01-12             NaN             NaN
# 2010-01-13             NaN             NaN
# 2010-01-14             NaN             NaN
# 2010-01-15             NaN             NaN
# 2010-01-16             NaN             NaN
# 2010-01-17             NaN             NaN
# 2010-01-18             NaN             NaN
# 2010-01-19             NaN             NaN
# 2010-01-20             NaN             NaN
# 2010-01-21             NaN             NaN
# 2010-01-22             NaN             NaN
# 2010-01-23             NaN             NaN
# 2010-01-24             NaN             NaN
# 2010-01-25             NaN             NaN
# 2010-01-26             NaN             NaN
# 2010-01-27             NaN             NaN
# 2010-01-28             NaN             NaN
# 2010-01-29             NaN             NaN
# 2010-01-30             NaN             NaN
# 2010-01-31             NaN             NaN
#
# The Simulated dataframe for January 2010:
#
#             QOMEAS_05BB001  QOMEAS_05BA001
# 2010-01-01             NaN             NaN
# 2010-01-02             NaN             NaN
# 2010-01-03             NaN             NaN
# 2010-01-04             NaN             NaN
# 2010-01-05             NaN             NaN
# 2010-01-06             NaN             NaN
# 2010-01-07             NaN             NaN
# 2010-01-08             NaN             NaN
# 2010-01-09             NaN             NaN
# 2010-01-10             NaN             NaN
# 2010-01-11             NaN             NaN
# 2010-01-12             NaN             NaN
# 2010-01-13             NaN             NaN
# 2010-01-14             NaN             NaN
# 2010-01-15             NaN             NaN
# 2010-01-16             NaN             NaN
# 2010-01-17             NaN             NaN
# 2010-01-18             NaN             NaN
# 2010-01-19             NaN             NaN
# 2010-01-20             NaN             NaN
# 2010-01-21             NaN             NaN
# 2010-01-22             NaN             NaN
# 2010-01-23             NaN             NaN
# 2010-01-24             NaN             NaN
# 2010-01-25             NaN             NaN
# 2010-01-26             NaN             NaN
# 2010-01-27             NaN             NaN
# 2010-01-28             NaN             NaN
# 2010-01-29             NaN             NaN
# 2010-01-30             NaN             NaN
# 2010-01-31             NaN             NaN

# %%
print("The Merged dataframe until 2009: \n")
print(DATAFRAMES_till2009["DF"])
print("The Observed dataframe until 2009: \n")
print(DATAFRAMES_till2009["DF_OBSERVED"])
print("\nThe Simulated dataframe until 2009: \n")
print(DATAFRAMES_till2009["DF_SIMULATED"])
# Out:
# The Merged dataframe until 2009:
#
#             QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1980-12-31           10.20       2.530770             NaN       1.006860
# 1981-01-01            9.85       2.518999             NaN       1.001954
# 1981-01-02           10.20       2.507289             NaN       0.997078
# 1981-01-03           10.00       2.495637             NaN       0.992233
# 1981-01-04           10.10       2.484073             NaN       0.987417
# ...                    ...            ...             ...            ...
# 2009-12-27             NaN       4.114114             NaN       0.815359
# 2009-12-28             NaN       4.091105             NaN       0.810912
# 2009-12-29             NaN       4.068261             NaN       0.806497
# 2009-12-30             NaN       4.045577             NaN       0.802113
# 2009-12-31             NaN       4.023057             NaN       0.797758
#
# [10593 rows x 4 columns]
# The Observed dataframe until 2009:
#
#             QOMEAS_05BB001  QOMEAS_05BA001
# 1980-12-31           10.20             NaN
# 1981-01-01            9.85             NaN
# 1981-01-02           10.20             NaN
# 1981-01-03           10.00             NaN
# 1981-01-04           10.10             NaN
# ...                    ...             ...
# 2009-12-27             NaN             NaN
# 2009-12-28             NaN             NaN
# 2009-12-29             NaN             NaN
# 2009-12-30             NaN             NaN
# 2009-12-31             NaN             NaN
#
# [10593 rows x 2 columns]
#
# The Simulated dataframe until 2009:
#
#             QOSIM_05BB001  QOSIM_05BA001
# 1980-12-31       2.530770       1.006860
# 1981-01-01       2.518999       1.001954
# 1981-01-02       2.507289       0.997078
# 1981-01-03       2.495637       0.992233
# 1981-01-04       2.484073       0.987417
# ...                   ...            ...
# 2009-12-27       4.114114       0.815359
# 2009-12-28       4.091105       0.810912
# 2009-12-29       4.068261       0.806497
# 2009-12-30       4.045577       0.802113
# 2009-12-31       4.023057       0.797758
#
# [10593 rows x 2 columns]

# %%
print("The Merged dataframe from 1995: \n")
print(DATAFRAMES_from1995["DF"])
print("The Observed dataframe from 1995: \n")
print(DATAFRAMES_from1995["DF_OBSERVED"])
print("\nThe Simulated dataframe from 1995: \n")
print(DATAFRAMES_from1995["DF_SIMULATED"])
# Out:
# The Merged dataframe from 1995:
#
#             QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1995-01-01            8.37       3.170254             NaN       0.884237
# 1995-01-02           10.10       3.153162             NaN       0.879155
# 1995-01-03           12.20       3.136179             NaN       0.874110
# 1995-01-04           13.00       3.119328             NaN       0.869102
# 1995-01-05           13.20       3.102574             NaN       0.864132
# ...                    ...            ...             ...            ...
# 2017-12-27             NaN       4.418050             NaN       1.380227
# 2017-12-28             NaN       4.393084             NaN       1.372171
# 2017-12-29             NaN       4.368303             NaN       1.364174
# 2017-12-30             NaN       4.343699             NaN       1.356237
# 2017-12-31             NaN       4.319275             NaN       1.348359
#
# [8401 rows x 4 columns]
# The Observed dataframe from 1995:
#
#             QOMEAS_05BB001  QOMEAS_05BA001
# 1995-01-01            8.37             NaN
# 1995-01-02           10.10             NaN
# 1995-01-03           12.20             NaN
# 1995-01-04           13.00             NaN
# 1995-01-05           13.20             NaN
# ...                    ...             ...
# 2017-12-27             NaN             NaN
# 2017-12-28             NaN             NaN
# 2017-12-29             NaN             NaN
# 2017-12-30             NaN             NaN
# 2017-12-31             NaN             NaN
#
# [8401 rows x 2 columns]
#
# The Simulated dataframe from 1995:
#
#             QOSIM_05BB001  QOSIM_05BA001
# 1995-01-01       3.170254       0.884237
# 1995-01-02       3.153162       0.879155
# 1995-01-03       3.136179       0.874110
# 1995-01-04       3.119328       0.869102
# 1995-01-05       3.102574       0.864132
# ...                   ...            ...
# 2017-12-27       4.418050       1.380227
# 2017-12-28       4.393084       1.372171
# 2017-12-29       4.368303       1.364174
# 2017-12-30       4.343699       1.356237
# 2017-12-31       4.319275       1.348359
#
# [8401 rows x 2 columns]

# %% [markdown]
# You are also able to go a step further by aggregating your data right from the beggining by using the optional arguments

# %%
## Lets use a time period of 1981 to 1990 to demonstrate this
DATAFRAMES = data.generate_dataframes(csv_fpath=path, warm_up=365, start_date = "1981-01-01", end_date = "1990-12-31",
                                      # optional arguments
                                      # lets see a weekly aggregation
                                      daily_agg = True, da_method = 'min',
                                      # lets see a weekly aggregation
                                      weekly_agg = True, wa_method = 'min',
                                      # lets also see monthly aggregation
                                      monthly_agg = True, ma_method = 'inst',
                                      # lets also see yearly aggregation
                                      yearly_agg = True, ya_method = 'sum'
                                      # note that without inputing the respective methods,
                                      # the functions default to mean as the method of aggregation
                                     )
for key, value in DATAFRAMES.items():
    print(f"{key}:\n{value}")
    
# You can uncomment these lines to help with manual confirmation of the data generated 
# DATAFRAMES["DF_WEEKLY"].to_csv('weekly_df.csv')
# DATAFRAMES["DF_MONTHLY"].to_csv('monthly_df.csv')
# DATAFRAMES["DF_YEARLY"].to_csv('yearly_df.csv')
# Out:
# DF:
#             QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981-01-01            9.85       2.518999             NaN       1.001954
# 1981-01-02           10.20       2.507289             NaN       0.997078
# 1981-01-03           10.00       2.495637             NaN       0.992233
# 1981-01-04           10.10       2.484073             NaN       0.987417
# 1981-01-05            9.99       2.472571             NaN       0.982631
# ...                    ...            ...             ...            ...
# 1990-12-27           10.10       6.615961             NaN       1.737144
# 1990-12-28            9.50       6.573054             NaN       1.725025
# 1990-12-29            8.60       6.530500             NaN       1.713013
# 1990-12-30            8.20       6.488300             NaN       1.701107
# 1990-12-31            8.25       6.446449             NaN       1.689308
#
# [3652 rows x 4 columns]
# DF_SIMULATED:
#             QOSIM_05BB001  QOSIM_05BA001
# 1981-01-01       2.518999       1.001954
# 1981-01-02       2.507289       0.997078
# 1981-01-03       2.495637       0.992233
# 1981-01-04       2.484073       0.987417
# 1981-01-05       2.472571       0.982631
# ...                   ...            ...
# 1990-12-27       6.615961       1.737144
# 1990-12-28       6.573054       1.725025
# 1990-12-29       6.530500       1.713013
# 1990-12-30       6.488300       1.701107
# 1990-12-31       6.446449       1.689308
#
# [3652 rows x 2 columns]
# DF_OBSERVED:
#             QOMEAS_05BB001  QOMEAS_05BA001
# 1981-01-01            9.85             NaN
# 1981-01-02           10.20             NaN
# 1981-01-03           10.00             NaN
# 1981-01-04           10.10             NaN
# 1981-01-05            9.99             NaN
# ...                    ...             ...
# 1990-12-27           10.10             NaN
# 1990-12-28            9.50             NaN
# 1990-12-29            8.60             NaN
# 1990-12-30            8.20             NaN
# 1990-12-31            8.25             NaN
#
# [3652 rows x 2 columns]
# DF_DAILY:
#           QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981/001            9.85       2.518999             NaN       1.001954
# 1981/002           10.20       2.507289             NaN       0.997078
# 1981/003           10.00       2.495637             NaN       0.992233
# 1981/004           10.10       2.484073             NaN       0.987417
# 1981/005            9.99       2.472571             NaN       0.982631
# ...                  ...            ...             ...            ...
# 1990/361           10.10       6.615961             NaN       1.737144
# 1990/362            9.50       6.573054             NaN       1.725025
# 1990/363            8.60       6.530500             NaN       1.713013
# 1990/364            8.20       6.488300             NaN       1.701107
# 1990/365            8.25       6.446449             NaN       1.689308
#
# [3652 rows x 4 columns]
# DF_WEEKLY:
#          QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981.00            9.85       2.495637             NaN       0.992233
# 1981.01            8.70       2.416050             NaN       0.959137
# 1981.02            8.24       2.339655             NaN       0.927429
# 1981.03            7.86       2.266305             NaN       0.897038
# 1981.04            7.88       2.195846             NaN       0.867900
# ...                 ...            ...             ...            ...
# 1990.48           10.80       7.504057             NaN       1.989616
# 1990.49            9.20       7.160021             NaN       1.891450
# 1990.50            8.10       6.835969             NaN       1.799404
# 1990.51            8.60       6.530500             NaN       1.713013
# 1990.52            8.20       6.446449             NaN       1.689308
#
# [530 rows x 4 columns]
# DF_MONTHLY:
#          QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981-01            8.62       2.195846             NaN       0.867900
# 1981-02            7.20       1.940355             NaN       0.762678
# 1981-03            7.25       1.699932             NaN       0.664341
# 1981-04           15.30       3.859564             NaN       0.584523
# 1981-05          113.00     220.485800           28.20      96.363520
# ...                 ...            ...             ...            ...
# 1990-08           33.60      40.431200           10.10      23.856810
# 1990-09           90.90      19.438340           30.50       6.175078
# 1990-10           21.10       9.648046            4.01       2.642092
# 1990-11           12.00       7.920140            3.90       2.109938
# 1990-12            8.25       6.446449             NaN       1.689308
#
# [120 rows x 4 columns]
# DF_YEARLY:
#       QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981        10386.27    9273.383180         2424.26    4007.949313
# 1982        12635.47    8874.369067         3163.23    4123.606233
# 1983        11909.23    8214.793557         3198.17    3810.515038
# 1984        13298.33    7459.351671         2699.42    3431.981225
# 1985        13730.50    8487.241498         2992.40    3756.822014
# 1986        12576.84   10651.883689         3103.15    4794.825198
# 1987        15066.57    8947.025052         3599.74    4260.917801
# 1988        12642.53   10377.241643         2972.87    4614.234614
# 1989        10860.93   11118.336160         2624.79    5193.322199
# 1990        11129.76   11226.011936         2650.50    5273.448490

# %% [markdown]
# Observe how the methods inputed dictate the means of aggregation

# %% [markdown]
# We are also able to obtain a seasonal period from this step as show below

# %%
DATAFRAMES = data.generate_dataframes(csv_fpath=path, warm_up=365, start_date = "1981-01-01", end_date = "1990-12-31",
                                      # seasonal aggregation
                                      # obtaining the month of January from every year from 1981 to 1985
                                      seasonal_p = True, sp_dperiod = ('04-01', '08-30'),
                                      sp_subset = ('1981-01-01', '1985-12-31')
                                      # if the time range is not specified, it will return the daily period
                                      # for the whole data whose time frame might be specified by the start and
                                      # end date parameters
                                     )
for key, value in DATAFRAMES.items():
    print(f"{key}:\n{value}")

# You can uncomment this line to help with manual confirmation of the data generated 
# DATAFRAMES["DF_CUSTOM"].to_csv('seasonal_df.csv')
# DATAFRAMES["DF_CUSTOM"].head(40)
# Out:
# DF:
#             QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981-01-01            9.85       2.518999             NaN       1.001954
# 1981-01-02           10.20       2.507289             NaN       0.997078
# 1981-01-03           10.00       2.495637             NaN       0.992233
# 1981-01-04           10.10       2.484073             NaN       0.987417
# 1981-01-05            9.99       2.472571             NaN       0.982631
# ...                    ...            ...             ...            ...
# 1990-12-27           10.10       6.615961             NaN       1.737144
# 1990-12-28            9.50       6.573054             NaN       1.725025
# 1990-12-29            8.60       6.530500             NaN       1.713013
# 1990-12-30            8.20       6.488300             NaN       1.701107
# 1990-12-31            8.25       6.446449             NaN       1.689308
#
# [3652 rows x 4 columns]
# DF_SIMULATED:
#             QOSIM_05BB001  QOSIM_05BA001
# 1981-01-01       2.518999       1.001954
# 1981-01-02       2.507289       0.997078
# 1981-01-03       2.495637       0.992233
# 1981-01-04       2.484073       0.987417
# 1981-01-05       2.472571       0.982631
# ...                   ...            ...
# 1990-12-27       6.615961       1.737144
# 1990-12-28       6.573054       1.725025
# 1990-12-29       6.530500       1.713013
# 1990-12-30       6.488300       1.701107
# 1990-12-31       6.446449       1.689308
#
# [3652 rows x 2 columns]
# DF_OBSERVED:
#             QOMEAS_05BB001  QOMEAS_05BA001
# 1981-01-01            9.85             NaN
# 1981-01-02           10.20             NaN
# 1981-01-03           10.00             NaN
# 1981-01-04           10.10             NaN
# 1981-01-05            9.99             NaN
# ...                    ...             ...
# 1990-12-27           10.10             NaN
# 1990-12-28            9.50             NaN
# 1990-12-29            8.60             NaN
# 1990-12-30            8.20             NaN
# 1990-12-31            8.25             NaN
#
# [3652 rows x 2 columns]
# DF_CUSTOM:
#             QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981-04-01            7.04       1.692827             NaN       0.661448
# 1981-04-02            7.13       1.685759             NaN       0.658559
# 1981-04-03            7.29       1.678715             NaN       0.655694
# 1981-04-04            7.22       1.671718             NaN       0.652846
# 1981-04-05            7.06       1.664760             NaN       0.650011
# ...                    ...            ...             ...            ...
# 1985-08-26           45.90      22.102120            13.0      13.373290
# 1985-08-27           43.60      21.293030            12.5      12.981310
# 1985-08-28           42.50      21.262790            12.4      13.329020
# 1985-08-29           41.60      21.753170            12.8      13.696490
# 1985-08-30           42.00      22.593580            13.2      16.211630
#
# [760 rows x 4 columns]

# %% [markdown]
# Again observe how there is always an observed and simulated dataframe

# %% [markdown]
# If the above weekly and daily aggregations werent done at the beginning you are also able to do them whenever you want during your evaluation using their respective functions

# %%
# calculating the daily aggregate outside the generate dataframe function
merged_df = DATAFRAMES["DF"]
print(merged_df)
print(data.daily_aggregate(df=merged_df))
# Out:
#             QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981-01-01            9.85       2.518999             NaN       1.001954
# 1981-01-02           10.20       2.507289             NaN       0.997078
# 1981-01-03           10.00       2.495637             NaN       0.992233
# 1981-01-04           10.10       2.484073             NaN       0.987417
# 1981-01-05            9.99       2.472571             NaN       0.982631
# ...                    ...            ...             ...            ...
# 1990-12-27           10.10       6.615961             NaN       1.737144
# 1990-12-28            9.50       6.573054             NaN       1.725025
# 1990-12-29            8.60       6.530500             NaN       1.713013
# 1990-12-30            8.20       6.488300             NaN       1.701107
# 1990-12-31            8.25       6.446449             NaN       1.689308
#
# [3652 rows x 4 columns]
#           QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981/001            9.85       2.518999             NaN       1.001954
# 1981/002           10.20       2.507289             NaN       0.997078
# 1981/003           10.00       2.495637             NaN       0.992233
# 1981/004           10.10       2.484073             NaN       0.987417
# 1981/005            9.99       2.472571             NaN       0.982631
# ...                  ...            ...             ...            ...
# 1990/361           10.10       6.615961             NaN       1.737144
# 1990/362            9.50       6.573054             NaN       1.725025
# 1990/363            8.60       6.530500             NaN       1.713013
# 1990/364            8.20       6.488300             NaN       1.701107
# 1990/365            8.25       6.446449             NaN       1.689308
#
# [3652 rows x 4 columns]

# %%
# We are also able to do the same weekly...
# Recall that the default method is mean
print(data.weekly_aggregate(df=merged_df, method="min"))
# Out:
#          QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981.00            9.85       2.495637             NaN       0.992233
# 1981.01            8.70       2.416050             NaN       0.959137
# 1981.02            8.24       2.339655             NaN       0.927429
# 1981.03            7.86       2.266305             NaN       0.897038
# 1981.04            7.88       2.195846             NaN       0.867900
# ...                 ...            ...             ...            ...
# 1990.48           10.80       7.504057             NaN       1.989616
# 1990.49            9.20       7.160021             NaN       1.891450
# 1990.50            8.10       6.835969             NaN       1.799404
# 1990.51            8.60       6.530500             NaN       1.713013
# 1990.52            8.20       6.446449             NaN       1.689308
#
# [530 rows x 4 columns]

# %%
# Monthly...
print(data.monthly_aggregate(df=merged_df, method="inst"))
# Out:
#          QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981-01            8.62       2.195846             NaN       0.867900
# 1981-02            7.20       1.940355             NaN       0.762678
# 1981-03            7.25       1.699932             NaN       0.664341
# 1981-04           15.30       3.859564             NaN       0.584523
# 1981-05          113.00     220.485800           28.20      96.363520
# ...                 ...            ...             ...            ...
# 1990-08           33.60      40.431200           10.10      23.856810
# 1990-09           90.90      19.438340           30.50       6.175078
# 1990-10           21.10       9.648046            4.01       2.642092
# 1990-11           12.00       7.920140            3.90       2.109938
# 1990-12            8.25       6.446449             NaN       1.689308
#
# [120 rows x 4 columns]

# %%
# Yearly...
print(data.yearly_aggregate(df=merged_df, method="sum"))
# Out:
#       QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981        10386.27    9273.383180         2424.26    4007.949313
# 1982        12635.47    8874.369067         3163.23    4123.606233
# 1983        11909.23    8214.793557         3198.17    3810.515038
# 1984        13298.33    7459.351671         2699.42    3431.981225
# 1985        13730.50    8487.241498         2992.40    3756.822014
# 1986        12576.84   10651.883689         3103.15    4794.825198
# 1987        15066.57    8947.025052         3599.74    4260.917801
# 1988        12642.53   10377.241643         2972.87    4614.234614
# 1989        10860.93   11118.336160         2624.79    5193.322199
# 1990        11129.76   11226.011936         2650.50    5273.448490

# %%
# and we are also able to obtaining a customized seasonal period...
print(data.seasonal_period(df=merged_df, daily_period=('01-01', '01-31'), subset = ('1981-01-01', '1985-12-31')))
# Out:
#             QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981-01-01            9.85       2.518999             NaN       1.001954
# 1981-01-02           10.20       2.507289             NaN       0.997078
# 1981-01-03           10.00       2.495637             NaN       0.992233
# 1981-01-04           10.10       2.484073             NaN       0.987417
# 1981-01-05            9.99       2.472571             NaN       0.982631
# ...                    ...            ...             ...            ...
# 1985-01-27           11.40       2.734883             NaN       0.809116
# 1985-01-28           11.60       2.721414             NaN       0.805189
# 1985-01-29           11.70       2.708047             NaN       0.801287
# 1985-01-30           11.60       2.694749             NaN       0.797410
# 1985-01-31           11.60       2.681550             NaN       0.793556
#
# [155 rows x 4 columns]

# %% [markdown]
# Finally, we are able to extract each station from the data

# %%
## for ease of code I will rename the variables
DATAFRAMES = data.generate_dataframes(csv_fpath=path, warm_up=365)
observed = DATAFRAMES["DF_OBSERVED"]
simulated = DATAFRAMES["DF_SIMULATED"]

# %%
# You are also able to split the data into their respective stations in the cases where you might want to do so
for station in data.station_dataframe(observed=observed, simulated=simulated):
    print(station)
# Out:
#             QOMEAS_05BB001  QOSIM_05BB001
# 1980-12-31           10.20       2.530770
# 1981-01-01            9.85       2.518999
# 1981-01-02           10.20       2.507289
# 1981-01-03           10.00       2.495637
# 1981-01-04           10.10       2.484073
# ...                    ...            ...
# 2017-12-27             NaN       4.418050
# 2017-12-28             NaN       4.393084
# 2017-12-29             NaN       4.368303
# 2017-12-30             NaN       4.343699
# 2017-12-31             NaN       4.319275
#
# [13515 rows x 2 columns]
#             QOMEAS_05BA001  QOSIM_05BA001
# 1980-12-31             NaN       1.006860
# 1981-01-01             NaN       1.001954
# 1981-01-02             NaN       0.997078
# 1981-01-03             NaN       0.992233
# 1981-01-04             NaN       0.987417
# ...                    ...            ...
# 2017-12-27             NaN       1.380227
# 2017-12-28             NaN       1.372171
# 2017-12-29             NaN       1.364174
# 2017-12-30             NaN       1.356237
# 2017-12-31             NaN       1.348359
#
# [13515 rows x 2 columns]

# %% [markdown]
# <mark>Note: As it stands, that is the only kind of data that we it is currently able to handle. In future releases, It will be able to handle more file types including, netcdf file, shape file, arrays, and more.<mark/>

# %% [markdown]
# ### Analysis

# %% [markdown]
# Because the library is in active development, there will be regular removals and additions to its features. As a rule of thumb therefore it is always a good idea to check what it can do at the time of use.

# %%
# We do this by calling on its available metrics
for metric in metrics.available_metrics():
    print(metric)
# Out:
# MSE
# RMSE
# MAE
# NSE
# NegNSE
# LogNSE
# NegLogNSE
# KGE
# NegKGE
# KGE 2012
# BIAS
# AbsBIAS
# TTP
# TTCoM
# SPOD

# %% [markdown]
# Now that we know what it can currently do, we know what we want to ask for.

# %% [markdown]
# ##### Mean Square Error

# %%
# Mean square error for the first station in the data we were given
print(metrics.mse(observed=observed, simulated=simulated))
# Out:
# [1657.0, 730.4]

# %% [markdown]
# ##### Root Mean Square Error

# %%
# lets calculate for the root mean square error for the first station in the data we were given
# The syntax goes:-
print(metrics.rmse(observed=observed, simulated=simulated))
# Out:
# [40.7, 27.03]

# %% [markdown]
# ##### Mean Average Error

# %%
# Similarly, the mean absolute error for the first station in the data we were given will look like 
print(metrics.mae(observed=observed, simulated=simulated))
# Out:
# [22.13, 13.56]

# %% [markdown]
# ##### Nash-Sutcliffe Efficiency

# %%
# Similarly, the Nash-Sutcliffe Efficiency for the first station in the data we were given will look like 
print(metrics.nse(observed=observed, simulated=simulated))
# Out:
# [0.002181, -4.825]

# %% [markdown]
# ##### Kling-Gupta Efficiency

# %%
# Similarly, the Kling-Gupta Efficiency for the first station in the data we were given will look like 
print(metrics.kge(observed=observed, simulated=simulated))
# Out:
# [0.4906, -0.7628]

# %% [markdown]
# ##### The Updated Kling-Gupta Efficiency (2012)

# %%
# Similarly, the Kling-Gupta Efficiency for the first station in the data we were given will look like 
print(metrics.kge_2012(observed=observed, simulated=simulated))
# Out:
# [0.2781, -0.1909]

# %% [markdown]
# ##### Percentage Bias

# %%
# Similarly, the Percentage Bias for the first station in the data we were given will look like 
print(metrics.bias(observed=observed, simulated=simulated))

# Observed that it returns the percentage not the actual value i.e 27% not 0.27
# Out:
# [-27.05, 31.55]

# %% [markdown]
# ##### Time to Peak

# %%
# Similarly, the Time to Peak for the simulated data from the first station in the data we were given will look like 
print(metrics.time_to_peak(df=simulated))

# The time to peak for the observed data for the same station looks like:-
print(metrics.time_to_peak(df=observed))
# Out:
# [187.0, 173.0]
# [158.0, 171.0]

# %% [markdown]
# ##### Time to Centre of Mass

# %%
# Similarly, the Time to Peak for the simulated data from the first station in the data we were given will look like 
print(metrics.time_to_centre_of_mass(df=simulated))

# The time to peak for the observed data for the same station looks like:-
print(metrics.time_to_centre_of_mass(df=observed))
# Out:
# [193.0, 192.0]
# [183.0, 200.0]

# %% [markdown]
# ##### Spring Pulse Onset Delay

# %%
# Similarly, the Time to Peak for the simulated data from the first station in the data we were given will look like 
print(metrics.SpringPulseOnset(df=simulated))

# The time to peak for the observed data for the same station looks like:-
# print(metrics.SpringPulseOnset(df=observed))
# Out:
# [136.0, 143.0]

# %% [markdown]
# ##### Multiple metrics

# %%
# You are also able to calculate possible available metrics 
# for key, value in metrics.calculate_all_metrics(observed=observed, simulated=simulated, stations=[1, 2]).items():
#     print(f"{key}: {value}")

# %% [markdown]
# Note: There will be an option to have this returned in a text file for easy observation in the coming days

# %%
# Naturally, you are also able to calculate a few metrics at a time but putting then in a list and passing them into the function
# as shown below
metrices = ["MSE", "RMSE", "MAE", "NSE", "NegNSE", "LogNSE"]
for key, value in metrics.calculate_metrics(observed=observed, simulated=simulated, metrices=metrices).items():
    print(f"{key}: {value}")
# Out:
# MSE: [1657.0, 730.4]
# RMSE: [40.7, 27.03]
# MAE: [22.13, 13.56]
# NSE: [0.002181, -4.825]
# NegNSE: [-0.002181, 4.825]
# LogNSE: [-0.2379, -0.8608]

# %% [markdown]
# ### Visualizations

# %% [markdown]
# <mark>Note: The visualization modules are still under review<mark/>

# %%
visuals.plot(
    merged_df = DATAFRAMES["DF"]['1981-01-01':'1990-12-31'],
    title='Hydrograph of the time series from 1981-1990',
    linestyles=['r-', 'b-'],
    labels=['Datetime', 'Streamflow'],
    metrices=['RMSE', 'MAE', 'KGE'],
    linewidth = [.75, 1.25],
    grid=True,
    )

# %%
sim_monthly = data.monthly_aggregate(df=simulated)
obs_monthly = data.monthly_aggregate(df=observed)
Stations_by_monthly = data.station_dataframe(observed=obs_monthly, simulated=sim_monthly)
# plot of the second station in the dataframe within the time period aggregated monthly by mean(default)
visuals.plot(merged_df = Stations_by_monthly[1]['1981-01':'1990-12'],
            title='Hydrograph of the time series aggregated monthly from 1981-1990',
            linestyles=['r-', 'b-'],
            labels=['Datetime', 'Streamflow'],
            metrices=['RMSE', 'MSE', 'PBIAS'],
            grid = True
            )

# %%
visuals.scatter(merged_df = DATAFRAMES['DF']['1981-01-01':'1985-01-31'],
               grid = True,
               labels = ("Simulated", "Observed"),
               markerstyle = 'b.',
               title = "Scatterplot of January 1981 to January 1985",
               line45 = True,
               metrices = ['KGE', 'RMSE']
               )

# %%
# There is an optional dependency required with using read_excel so first we install it
# !pip install openpyxl

path_output_2 = "MESH_output_streamflow_2.csv"
path_input_2 = "Station_data.xlsx"


#### Newer data
DATA_2 = data.generate_dataframes(csv_fpath=path_output_2, warm_up=365,
                                 # long term
                                 long_term = True, lt_method = ["q33.33", "median" ,'q75' ,'Q25' ,'q33' ],)
Stations_2 = pd.read_excel(io=path_input_2)

ignore = []
for i in range(0, len(Stations_2)):
    if Stations_2['Properties'][i] == 'X':
        ignore.append(i)

Stations_2 = Stations_2.drop(Stations_2[Stations_2['Properties'] == 'X'].index)
Stations_2 = Stations_2.set_index('Station Number')

for i in reversed(ignore):
    DATA_2['DF'] = DATA_2['DF'].drop(columns = DATA_2['DF'].columns[[2*i, 2*i+1]])
    DATA_2["DF_OBSERVED"] = DATA_2["DF_OBSERVED"].drop(columns = DATA_2['DF_OBSERVED'].columns[i])
    DATA_2['DF_SIMULATED']  = DATA_2["DF_SIMULATED"].drop(columns = DATA_2['DF_SIMULATED'].columns[i])

# %%
shapefile_path = r"SaskRB_SubDrainage2.shp"

visuals.scatter(shapefile_path = shapefile_path,
                        title = "SRB SubDrainage and KGE",
                        x_axis = Stations_2["Lon"],
                        y_axis = Stations_2["Lat"],
                        metric = "KGE",
                        fig_size = (24, 30),
                        observed = DATA_2["DF_OBSERVED"],
                        simulated = DATA_2["DF_SIMULATED"],
                        labels=['Longitude', 'Latitude'],
                    )
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[40], line 3
#       1 shapefile_path = r"SaskRB_SubDrainage2.shp"
# ----> 3 visuals.scatter(shapefile_path = shapefile_path,
#       4                         title = ["SRB SubDrainage and KGE"],
#       5                         x_axis = Stations_2["Lon"],
#       6                         y_axis = Stations_2["Lat"],
#       7                         metric = "KGE",
#       8                         fig_size = (24, 30),
#       9                         observed = DATA_2["DF_OBSERVED"],
#      10                         simulated = DATA_2["DF_SIMULATED"],
#      11                         labels=['Longitude', 'Latitude'],
#      12                     )
#
# File ~\Desktop\JUPYTER\postprocessing\docs\source\notebooks\../../..\postprocessinglib\evaluation\visuals.py:974, in scatter(grid, title, labels, fig_size, best_fit, line45, merged_df, obs_df, sim_df, metrices, markerstyle, save, metrics_adjust, plot_adjust, shapefile_path, x_axis, y_axis, metric, observed, simulated)
#     972 if isinstance(title, list):
#     973     try:
# --> 974         ax.set_title(label=title[i], fontdict=title_dict, pad=25)
#     975     except IndexError:
#     976         ax.set_title(label='Hydrograph of the time series', fontdict=title_dict, pad=25)
#
# UnboundLocalError: cannot access local variable 'i' where it is not associated with a value

# %%
DATAFRAMES = data.generate_dataframes(csv_fpath=path, warm_up=365, start_date = "1981-01-01", end_date = "1990-12-31",
                                      # optional arguments
                                      # lets see a weekly aggregation
                                      daily_agg = True, da_method = 'min',
                                      # lets see a weekly aggregation
                                      weekly_agg = True, wa_method = 'min',
                                      # lets also see monthly aggregation
                                      monthly_agg = True, ma_method = 'inst',
                                      # lets also see yearly aggregation
                                      yearly_agg = True, ya_method = 'sum',
                                      # seasonal aggregation
                                      # obtaining the month of January from every year from 1981 to 1985
                                      seasonal_p = True, sp_dperiod = ('04-01', '08-30'),
                                      sp_subset = ('1981-01-01', '1985-12-31'),
                                      # long term
                                      long_term = True, lt_method = ["q33.33", "median" ,'q75' ,'Q25' ,'q33' ],
                                     )
for key, value in DATAFRAMES.items():
    print(f"{key}:\n{value}")
# Out:
# DF:
#             QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981-01-01            9.85       2.518999             NaN       1.001954
# 1981-01-02           10.20       2.507289             NaN       0.997078
# 1981-01-03           10.00       2.495637             NaN       0.992233
# 1981-01-04           10.10       2.484073             NaN       0.987417
# 1981-01-05            9.99       2.472571             NaN       0.982631
# ...                    ...            ...             ...            ...
# 1990-12-27           10.10       6.615961             NaN       1.737144
# 1990-12-28            9.50       6.573054             NaN       1.725025
# 1990-12-29            8.60       6.530500             NaN       1.713013
# 1990-12-30            8.20       6.488300             NaN       1.701107
# 1990-12-31            8.25       6.446449             NaN       1.689308
#
# [3652 rows x 4 columns]
# DF_SIMULATED:
#             QOSIM_05BB001  QOSIM_05BA001
# 1981-01-01       2.518999       1.001954
# 1981-01-02       2.507289       0.997078
# 1981-01-03       2.495637       0.992233
# 1981-01-04       2.484073       0.987417
# 1981-01-05       2.472571       0.982631
# ...                   ...            ...
# 1990-12-27       6.615961       1.737144
# 1990-12-28       6.573054       1.725025
# 1990-12-29       6.530500       1.713013
# 1990-12-30       6.488300       1.701107
# 1990-12-31       6.446449       1.689308
#
# [3652 rows x 2 columns]
# DF_OBSERVED:
#             QOMEAS_05BB001  QOMEAS_05BA001
# 1981-01-01            9.85             NaN
# 1981-01-02           10.20             NaN
# 1981-01-03           10.00             NaN
# 1981-01-04           10.10             NaN
# 1981-01-05            9.99             NaN
# ...                    ...             ...
# 1990-12-27           10.10             NaN
# 1990-12-28            9.50             NaN
# 1990-12-29            8.60             NaN
# 1990-12-30            8.20             NaN
# 1990-12-31            8.25             NaN
#
# [3652 rows x 2 columns]
# DF_DAILY:
#           QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981/001            9.85       2.518999             NaN       1.001954
# 1981/002           10.20       2.507289             NaN       0.997078
# 1981/003           10.00       2.495637             NaN       0.992233
# 1981/004           10.10       2.484073             NaN       0.987417
# 1981/005            9.99       2.472571             NaN       0.982631
# ...                  ...            ...             ...            ...
# 1990/361           10.10       6.615961             NaN       1.737144
# 1990/362            9.50       6.573054             NaN       1.725025
# 1990/363            8.60       6.530500             NaN       1.713013
# 1990/364            8.20       6.488300             NaN       1.701107
# 1990/365            8.25       6.446449             NaN       1.689308
#
# [3652 rows x 4 columns]
# DF_WEEKLY:
#          QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981.00            9.85       2.495637             NaN       0.992233
# 1981.01            8.70       2.416050             NaN       0.959137
# 1981.02            8.24       2.339655             NaN       0.927429
# 1981.03            7.86       2.266305             NaN       0.897038
# 1981.04            7.88       2.195846             NaN       0.867900
# ...                 ...            ...             ...            ...
# 1990.48           10.80       7.504057             NaN       1.989616
# 1990.49            9.20       7.160021             NaN       1.891450
# 1990.50            8.10       6.835969             NaN       1.799404
# 1990.51            8.60       6.530500             NaN       1.713013
# 1990.52            8.20       6.446449             NaN       1.689308
#
# [530 rows x 4 columns]
# DF_MONTHLY:
#          QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981-01            8.62       2.195846             NaN       0.867900
# 1981-02            7.20       1.940355             NaN       0.762678
# 1981-03            7.25       1.699932             NaN       0.664341
# 1981-04           15.30       3.859564             NaN       0.584523
# 1981-05          113.00     220.485800           28.20      96.363520
# ...                 ...            ...             ...            ...
# 1990-08           33.60      40.431200           10.10      23.856810
# 1990-09           90.90      19.438340           30.50       6.175078
# 1990-10           21.10       9.648046            4.01       2.642092
# 1990-11           12.00       7.920140            3.90       2.109938
# 1990-12            8.25       6.446449             NaN       1.689308
#
# [120 rows x 4 columns]
# DF_YEARLY:
#       QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981        10386.27    9273.383180         2424.26    4007.949313
# 1982        12635.47    8874.369067         3163.23    4123.606233
# 1983        11909.23    8214.793557         3198.17    3810.515038
# 1984        13298.33    7459.351671         2699.42    3431.981225
# 1985        13730.50    8487.241498         2992.40    3756.822014
# 1986        12576.84   10651.883689         3103.15    4794.825198
# 1987        15066.57    8947.025052         3599.74    4260.917801
# 1988        12642.53   10377.241643         2972.87    4614.234614
# 1989        10860.93   11118.336160         2624.79    5193.322199
# 1990        11129.76   11226.011936         2650.50    5273.448490
# DF_CUSTOM:
#             QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# 1981-04-01            7.04       1.692827             NaN       0.661448
# 1981-04-02            7.13       1.685759             NaN       0.658559
# 1981-04-03            7.29       1.678715             NaN       0.655694
# 1981-04-04            7.22       1.671718             NaN       0.652846
# 1981-04-05            7.06       1.664760             NaN       0.650011
# ...                    ...            ...             ...            ...
# 1985-08-26           45.90      22.102120            13.0      13.373290
# 1985-08-27           43.60      21.293030            12.5      12.981310
# 1985-08-28           42.50      21.262790            12.4      13.329020
# 1985-08-29           41.60      21.753170            12.8      13.696490
# 1985-08-30           42.00      22.593580            13.2      16.211630
#
# [760 rows x 4 columns]
# LONG_TERM_MIN:
#       QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# jday
# 1               7.17       1.802230             NaN       0.485006
# 2               7.02       1.794152             NaN       0.482805
# 3               7.10       1.786115             NaN       0.480617
# 4               7.31       1.778133             NaN       0.478442
# 5               7.64       1.770190             NaN       0.476279
# ...              ...            ...             ...            ...
# 362             7.25       1.835014             NaN       0.493944
# 363             7.29       1.826749             NaN       0.491689
# 364             7.27       1.818528             NaN       0.489450
# 365             7.21       1.810352             NaN       0.487221
# 366            10.30       2.939887             NaN       0.782759
#
# [366 rows x 4 columns]
# LONG_TERM_MAX:
#       QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# jday
# 1               12.7       5.465301             NaN       2.441398
# 2               12.7       5.433753             NaN       2.426411
# 3               12.7       5.402424             NaN       2.411540
# 4               12.7       5.371336             NaN       2.396784
# 5               12.8       5.340471             NaN       2.382142
# ...              ...            ...             ...            ...
# 362             13.3       6.573054             NaN       2.502534
# 363             13.0       6.530500             NaN       2.487069
# 364             12.8       6.488300             NaN       2.471726
# 365             12.7       6.446449             NaN       2.456503
# 366             11.3       3.132862             NaN       0.925092
#
# [366 rows x 4 columns]
# LONG_TERM_MEAN:
#       QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# jday
# 1              9.813       3.603254             NaN       1.220004
# 2              9.891       3.583694             NaN       1.213043
# 3             10.009       3.564265             NaN       1.206132
# 4              9.982       3.544976             NaN       1.199272
# 5              9.898       3.525820             NaN       1.192462
# ...              ...            ...             ...            ...
# 362           10.227       4.086791             NaN       1.319624
# 363            9.834       4.063592             NaN       1.311746
# 364            9.671       4.040563             NaN       1.303929
# 365            9.680       4.017703             NaN       1.296171
# 366           10.800       3.036374             NaN       0.853926
#
# [366 rows x 4 columns]
# LONG_TERM_Q33.33:
#       QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# jday
# 1             9.5038       3.111064             NaN       0.883555
# 2             9.4119       3.095175             NaN       0.878476
# 3             9.5898       3.079368             NaN       0.873434
# 4             9.7091       3.063681             NaN       0.868430
# 5             9.4000       3.048084             NaN       0.863463
# ...              ...            ...             ...            ...
# 362           9.4817       3.368631             NaN       0.904254
# 363           8.8461       3.351331             NaN       0.899021
# 364           8.9470       3.334136             NaN       0.893827
# 365           8.9176       3.317062             NaN       0.888672
# 366          10.6300       3.003569             NaN       0.829729
#
# [366 rows x 4 columns]
# LONG_TERM_MEDIAN:
#       QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# jday
# 1              9.795       3.397196             NaN       0.961191
# 2              9.815       3.379185             NaN       0.956437
# 3              9.855       3.361293             NaN       0.951713
# 4              9.875       3.343524             NaN       0.947018
# 5              9.695       3.325880             NaN       0.942354
# ...              ...            ...             ...            ...
# 362           10.350       3.698825             NaN       1.020910
# 363            9.490       3.678319             NaN       1.015117
# 364            9.070       3.657953             NaN       1.009368
# 365            9.350       3.637736             NaN       1.003660
# 366           10.800       3.036374             NaN       0.853926
#
# [366 rows x 4 columns]
# LONG_TERM_Q75:
#       QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# jday
# 1            10.0375       4.156184             NaN       1.248870
# 2            10.2000       4.132273             NaN       1.242024
# 3            10.6500       4.108537             NaN       1.235226
# 4            10.3250       4.084971             NaN       1.228475
# 5            10.5225       4.061583             NaN       1.221772
# ...              ...            ...             ...            ...
# 362          11.2500       5.222542             NaN       1.627869
# 363          11.0000       5.192005             NaN       1.617079
# 364          10.8000       5.161703             NaN       1.606380
# 365          10.4950       5.131630             NaN       1.595775
# 366          11.0500       3.084618             NaN       0.889509
#
# [366 rows x 4 columns]
# LONG_TERM_Q25:
#       QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# jday
# 1             9.1150       2.972452             NaN       0.881223
# 2             9.2175       2.956880             NaN       0.876179
# 3             9.3450       2.941408             NaN       0.871171
# 4             9.6875       2.926045             NaN       0.866200
# 5             9.4000       2.910776             NaN       0.861267
# ...              ...            ...             ...            ...
# 362           9.0425       3.241984             NaN       0.901784
# 363           8.7525       3.225315             NaN       0.896586
# 364           8.8750       3.208758             NaN       0.891427
# 365           8.8600       3.192306             NaN       0.886306
# 366          10.5500       2.988131             NaN       0.818343
#
# [366 rows x 4 columns]
# LONG_TERM_Q33:
#       QOMEAS_05BB001  QOSIM_05BB001  QOMEAS_05BA001  QOSIM_05BA001
# jday
# 1             9.5038       3.111064             NaN       0.883555
# 2             9.4119       3.095175             NaN       0.878476
# 3             9.5898       3.079368             NaN       0.873434
# 4             9.7091       3.063681             NaN       0.868430
# 5             9.4000       3.048084             NaN       0.863463
# ...              ...            ...             ...            ...
# 362           9.4817       3.368631             NaN       0.904254
# 363           8.8461       3.351331             NaN       0.899021
# 364           8.9470       3.334136             NaN       0.893827
# 365           8.9176       3.317062             NaN       0.888672
# 366          10.6300       3.003569             NaN       0.829729
#
# [366 rows x 4 columns]

# %%
visuals.bounded_plot(
    lines = DATAFRAMES["LONG_TERM_MEDIAN"],#.iloc[:, [0, 1]],
    upper_bounds = [DATAFRAMES["LONG_TERM_Q75"], DATAFRAMES["LONG_TERM_MAX"]],
    lower_bounds = [DATAFRAMES["LONG_TERM_Q25"], DATAFRAMES["LONG_TERM_MIN"]],
    # upper_bounds = [DATAFRAMES["LONG_TERM_Q75"]],
    # lower_bounds = [DATAFRAMES["LONG_TERM_Q25"]],
    title='Long Term Aggregation by days of the Year',
    linestyles=['r-', 'b-'],
    labels=['Datetime', 'Streamflow'],
    grid=True
    )

# %%
for key, value in DATA_2.items():
    print(f"{key}:\n{value}")
# Out:
# DF:
#             QOMEAS1     QOSIM1  QOMEAS2    QOSIM2  QOMEAS3    QOSIM3  QOMEAS4  \
# 1982-10-02    15.00  12.710840      NaN  2.124695    1.840  1.442218     37.6
# 1982-10-03    14.80  12.064640      NaN  1.266883    1.840  1.223653     39.6
# 1982-10-04    15.20  11.925050      NaN  0.854982    1.690  1.083362     38.7
# 1982-10-05    15.00  11.872900      NaN  0.654379    1.580  0.989998     37.6
# 1982-10-06    14.10  11.844660      NaN  0.553681    1.430  0.916533     29.8
# ...             ...        ...      ...       ...      ...       ...      ...
# 2016-12-27     8.62   0.618894      NaN  0.422334    0.966  0.335788     20.7
# 2016-12-28     8.64   0.612090      NaN  0.421136    1.010  0.333170     22.0
# 2016-12-29     8.63   0.605523      NaN  0.419943    1.030  0.330585     24.5
# 2016-12-30     8.64   0.598825      NaN  0.418753    1.030  0.328032     25.5
# 2016-12-31     8.61   0.592695      NaN  0.417568    1.010  0.325506     25.1
#
#                QOSIM4  QOMEAS6     QOSIM6  ...  QOMEAS47   QOSIM47  QOMEAS48  \
# 1982-10-02  41.383090     31.2  82.203330  ...      1.48  0.004791     161.0
# 1982-10-03  28.755160     39.7  72.739070  ...      1.36  0.108130     162.0
# 1982-10-04  23.738560     41.9  58.247280  ...      1.29  0.113203     154.0
# 1982-10-05  21.844820     42.2  44.965800  ...      1.31  0.101313     147.0
# 1982-10-06  21.053230     42.4  35.552480  ...      1.48  0.296497     169.0
# ...               ...      ...        ...  ...       ...       ...       ...
# 2016-12-27   6.978114     21.7   7.124238  ...      1.65  0.099565     294.0
# 2016-12-28   6.963130     22.6   7.106165  ...      1.67  0.093154     291.0
# 2016-12-29   6.948433     24.3   7.088615  ...      1.70  0.087217     290.0
# 2016-12-30   6.934025     25.7   7.071548  ...      1.70  0.081708     291.0
# 2016-12-31   6.919834     25.8   7.054927  ...      1.71  0.076616     296.0
#
#              QOSIM48  QOMEAS52   QOSIM52  QOMEAS53    QOSIM53  QOMEAS54  \
# 1982-10-02  180.2208     359.0  345.2251      5.49   3.581287     345.0
# 1982-10-03  193.3808     209.0  342.8777      6.50   4.145184     354.0
# 1982-10-04  209.2575     316.0  342.7559      7.69   6.307367     416.0
# 1982-10-05  212.9623     351.0  339.7858      9.33  10.897350     422.0
# 1982-10-06  210.6800     319.0  337.6868     10.50  13.391670     382.0
# ...              ...       ...       ...       ...        ...       ...
# 2016-12-27  223.8501     301.0  345.0897       NaN   0.782658     646.0
# 2016-12-28  224.3529     424.0  342.9692       NaN   0.780110     628.0
# 2016-12-29  223.8014     450.0  345.2297       NaN   0.777413     615.0
# 2016-12-30  223.1730     413.0  343.1231       NaN   0.774460     603.0
# 2016-12-31  223.3189     415.0  340.9459       NaN   0.771303     597.0
#
#              QOSIM54
# 1982-10-02  434.5710
# 1982-10-03  423.4420
# 1982-10-04  409.4109
# 1982-10-05  398.8371
# 1982-10-06  393.0760
# ...              ...
# 2016-12-27  368.4555
# 2016-12-28  369.0828
# 2016-12-29  369.2430
# 2016-12-30  369.2756
# 2016-12-31  368.7908
#
# [12510 rows x 80 columns]
# DF_SIMULATED:
#                QOSIM1    QOSIM2    QOSIM3     QOSIM4     QOSIM6     QOSIM8  \
# 1982-10-02  12.710840  2.124695  1.442218  41.383090  82.203330  218.07070
# 1982-10-03  12.064640  1.266883  1.223653  28.755160  72.739070  192.54910
# 1982-10-04  11.925050  0.854982  1.083362  23.738560  58.247280  167.56530
# 1982-10-05  11.872900  0.654379  0.989998  21.844820  44.965800  139.26730
# 1982-10-06  11.844660  0.553681  0.916533  21.053230  35.552480  113.51930
# ...               ...       ...       ...        ...        ...        ...
# 2016-12-27   0.618894  0.422334  0.335788   6.978114   7.124238   27.51337
# 2016-12-28   0.612090  0.421136  0.333170   6.963130   7.106165   27.02631
# 2016-12-29   0.605523  0.419943  0.330585   6.948433   7.088615   26.70583
# 2016-12-30   0.598825  0.418753  0.328032   6.934025   7.071548   26.46758
# 2016-12-31   0.592695  0.417568  0.325506   6.919834   7.054927   26.26740
#
#               QOSIM9   QOSIM10   QOSIM11   QOSIM12  ...   QOSIM39   QOSIM40  \
# 1982-10-02  2.285669  9.455598  28.32853  1.145944  ...  0.054814  0.492489
# 1982-10-03  2.292851  9.953567  28.30430  1.145944  ...  0.080209  0.457249
# 1982-10-04  2.049895  9.527401  28.19594  1.145944  ...  0.134551  0.445425
# 1982-10-05  1.870752  8.457590  27.18470  1.145944  ...  0.212223  0.433742
# 1982-10-06  1.744765  7.600263  25.87970  1.145944  ...  0.355612  0.418686
# ...              ...       ...       ...       ...  ...       ...       ...
# 2016-12-27  0.379620  2.193217  16.16448  4.180817  ...  0.010938  0.058624
# 2016-12-28  0.375015  2.164594  16.02859  4.180817  ...  0.010710  0.056942
# 2016-12-29  0.370511  2.136342  15.89526  4.180817  ...  0.010499  0.055307
# 2016-12-30  0.366090  2.103930  15.76274  4.180817  ...  0.010301  0.053720
# 2016-12-31  0.361750  2.073366  15.62861  4.180817  ...  0.010118  0.052181
#
#              QOSIM41    QOSIM42   QOSIM46   QOSIM47   QOSIM48   QOSIM52  \
# 1982-10-02  1.409764   7.594512  136.6672  0.004791  180.2208  345.2251
# 1982-10-03  1.376128  13.828560  134.5253  0.108130  193.3808  342.8777
# 1982-10-04  1.598315  26.907240  132.8431  0.113203  209.2575  342.7559
# 1982-10-05  1.656257  22.339010  131.2007  0.101313  212.9623  339.7858
# 1982-10-06  1.625622  15.675110  129.6111  0.296497  210.6800  337.6868
# ...              ...        ...       ...       ...       ...       ...
# 2016-12-27  0.110838   0.294284  109.6402  0.099565  223.8501  345.0897
# 2016-12-28  0.108474   0.292683  109.4021  0.093154  224.3529  342.9692
# 2016-12-29  0.106168   0.291006  109.1618  0.087217  223.8014  345.2297
# 2016-12-30  0.103918   0.289253  108.9250  0.081708  223.1730  343.1231
# 2016-12-31  0.101721   0.287422  108.6938  0.076616  223.3189  340.9459
#
#               QOSIM53   QOSIM54
# 1982-10-02   3.581287  434.5710
# 1982-10-03   4.145184  423.4420
# 1982-10-04   6.307367  409.4109
# 1982-10-05  10.897350  398.8371
# 1982-10-06  13.391670  393.0760
# ...               ...       ...
# 2016-12-27   0.782658  368.4555
# 2016-12-28   0.780110  369.0828
# 2016-12-29   0.777413  369.2430
# 2016-12-30   0.774460  369.2756
# 2016-12-31   0.771303  368.7908
#
# [12510 rows x 40 columns]
# DF_OBSERVED:
#             QOMEAS1  QOMEAS2  QOMEAS3  QOMEAS4  QOMEAS6  QOMEAS8  QOMEAS9  \
# 1982-10-02    15.00      NaN    1.840     37.6     31.2     85.4     7.91
# 1982-10-03    14.80      NaN    1.840     39.6     39.7     65.8     7.88
# 1982-10-04    15.20      NaN    1.690     38.7     41.9     60.9     7.35
# 1982-10-05    15.00      NaN    1.580     37.6     42.2     56.9     6.87
# 1982-10-06    14.10      NaN    1.430     29.8     42.4     59.2     6.51
# ...             ...      ...      ...      ...      ...      ...      ...
# 2016-12-27     8.62      NaN    0.966     20.7     21.7     82.6      NaN
# 2016-12-28     8.64      NaN    1.010     22.0     22.6     85.5      NaN
# 2016-12-29     8.63      NaN    1.030     24.5     24.3     86.4      NaN
# 2016-12-30     8.64      NaN    1.030     25.5     25.7     85.6      NaN
# 2016-12-31     8.61      NaN    1.010     25.1     25.8     83.5      NaN
#
#             QOMEAS10  QOMEAS11  QOMEAS12  ...  QOMEAS39  QOMEAS40  QOMEAS41  \
# 1982-10-02      31.5      56.0     0.057  ...     1.610      4.87       NaN
# 1982-10-03      31.6      44.9     0.057  ...     1.730      5.71       NaN
# 1982-10-04      30.8      53.8     8.350  ...     1.930      6.43       NaN
# 1982-10-05      29.5      53.4     8.270  ...     2.640      6.12       NaN
# 1982-10-06      28.6      56.3     8.300  ...     3.270      5.59       NaN
# ...              ...       ...       ...  ...       ...       ...       ...
# 2016-12-27      11.7      40.0       NaN  ...     0.186       NaN       NaN
# 2016-12-28      12.2      43.0       NaN  ...     0.188       NaN       NaN
# 2016-12-29      11.8      44.6       NaN  ...     0.190       NaN       NaN
# 2016-12-30      11.5      51.5       NaN  ...     0.186       NaN       NaN
# 2016-12-31      11.2      42.3       NaN  ...     0.172       NaN       NaN
#
#             QOMEAS42  QOMEAS46  QOMEAS47  QOMEAS48  QOMEAS52  QOMEAS53  \
# 1982-10-02     7.230     210.0      1.48     161.0     359.0      5.49
# 1982-10-03     7.150     197.0      1.36     162.0     209.0      6.50
# 1982-10-04     7.510     190.0      1.29     154.0     316.0      7.69
# 1982-10-05     7.710     180.0      1.31     147.0     351.0      9.33
# 1982-10-06     7.320     181.0      1.48     169.0     319.0     10.50
# ...              ...       ...       ...       ...       ...       ...
# 2016-12-27     0.747     191.0      1.65     294.0     301.0       NaN
# 2016-12-28     0.720     197.0      1.67     291.0     424.0       NaN
# 2016-12-29     0.694     197.0      1.70     290.0     450.0       NaN
# 2016-12-30     0.668     189.0      1.70     291.0     413.0       NaN
# 2016-12-31     0.644     181.0      1.71     296.0     415.0       NaN
#
#             QOMEAS54
# 1982-10-02     345.0
# 1982-10-03     354.0
# 1982-10-04     416.0
# 1982-10-05     422.0
# 1982-10-06     382.0
# ...              ...
# 2016-12-27     646.0
# 2016-12-28     628.0
# 2016-12-29     615.0
# 2016-12-30     603.0
# 2016-12-31     597.0
#
# [12510 rows x 40 columns]
# LONG_TERM_MIN:
#       QOMEAS1    QOSIM1  QOMEAS2    QOSIM2  QOMEAS3    QOSIM3  QOMEAS4  \
# jday
# 1        4.95  0.285775      NaN  0.279818    0.090  0.205531     7.00
# 2        4.90  0.283049      NaN  0.288236    0.084  0.203812     6.80
# 3        4.55  0.280776      NaN  0.312031    0.084  0.202119     6.80
# 4        3.95  0.278347      NaN  0.334456    0.168  0.200453     6.70
# 5        3.91  0.276712      NaN  0.347390    0.109  0.198812     6.70
# ...       ...       ...      ...       ...      ...       ...      ...
# 362      4.80  0.297774      NaN  0.283547    0.107  0.212681     6.47
# 363      4.75  0.295330      NaN  0.282737    0.042  0.210852     5.76
# 364      4.80  0.292768      NaN  0.281928    0.024  0.209051     5.94
# 365      4.82  0.290453      NaN  0.281122    0.035  0.207277     5.91
# 366      4.85  0.288112      NaN  0.280318    0.245  0.207819     7.04
#
#         QOSIM4  QOMEAS5    QOSIM5  ...  QOMEAS50   QOSIM50  QOMEAS51  \
# jday                               ...
# 1     4.266197    0.680  2.582144  ...       NaN  0.008276     0.061
# 2     4.148757    0.700  2.471268  ...       NaN  0.008091     0.069
# 3     4.058642    0.730  2.467387  ...       NaN  0.007912     0.064
# 4     4.018508    0.730  2.467185  ...       NaN  0.007739     0.055
# 5     4.003016    0.725  2.467030  ...       NaN  0.007572     0.056
# ...        ...      ...       ...  ...       ...       ...       ...
# 362   4.348349    0.640  2.703247  ...       NaN  0.009233     0.061
# 363   4.334518    0.640  2.703247  ...       NaN  0.009046     0.055
# 364   4.320900    0.640  2.703247  ...       NaN  0.008865     0.052
# 365   4.307388    0.640  2.703247  ...       NaN  0.008665     0.055
# 366   4.293892    0.640  2.703247  ...       NaN  0.008467     0.173
#
#        QOSIM51  QOMEAS52   QOSIM52  QOMEAS53   QOSIM53  QOMEAS54   QOSIM54
# jday
# 1     0.020860     164.0  254.2864     0.363  0.061882     164.0  240.6751
# 2     0.020417     166.0  250.4615     0.357  0.061721     161.0  244.4548
# 3     0.019988     168.0  250.0191     0.363  0.061579     159.0  248.7123
# 4     0.019574     160.0  252.1400     0.389  0.061456     157.0  253.3548
# 5     0.019174     167.0  254.0905     0.415  0.061348     152.0  255.2375
# ...        ...       ...       ...       ...       ...       ...       ...
# 362   0.022680     154.0  238.9610     0.648  0.062654     173.0  233.0816
# 363   0.022252     183.0  242.6479     0.644  0.062449     174.0  233.9333
# 364   0.021836     148.0  245.9074     0.577  0.062250     171.0  234.3932
# 365   0.021433     150.0  252.2693     0.384  0.062060     168.0  236.9687
# 366   0.021320     165.0  328.8025     0.792  0.101037     173.0  330.7196
#
# [366 rows x 108 columns]
# LONG_TERM_MAX:
#       QOMEAS1    QOSIM1  QOMEAS2    QOSIM2  QOMEAS3    QOSIM3  QOMEAS4  \
# jday
# 1        26.8  8.915924      NaN  1.774750     2.77  2.805969     67.0
# 2        26.7  8.925565      NaN  1.803398     2.64  2.786096     66.9
# 3        26.9  8.918386      NaN  1.829603     2.28  2.769279     61.6
# 4        26.9  8.908811      NaN  1.832626     2.27  2.753603     62.7
# 5        26.9  8.898917      NaN  1.828222     2.36  2.737837     50.7
# ...       ...       ...      ...       ...      ...       ...      ...
# 362      26.8  8.931853      NaN  1.795133     2.57  2.897681     70.7
# 363      26.8  8.921513      NaN  1.789397     2.50  2.878000     67.0
# 364      26.8  8.911206      NaN  1.783689     2.74  2.853904     65.5
# 365      26.8  8.900962      NaN  1.777972     2.08  2.829023     62.6
# 366      10.8  7.705820      NaN  0.760156     1.92  0.940615     37.7
#
#         QOSIM4  QOMEAS5    QOSIM5  ...  QOMEAS50   QOSIM50  QOMEAS51  \
# jday                               ...
# 1     23.58243    20.50  4.251778  ...       NaN  3.733915     0.804
# 2     22.79053    20.60  4.046327  ...       NaN  3.699463     0.716
# 3     21.96087    19.20  4.031332  ...       NaN  3.665627     0.714
# 4     21.77105    17.90  4.027362  ...       NaN  3.632402     0.696
# 5     21.72835    16.50  4.023408  ...       NaN  3.599773     0.689
# ...        ...      ...       ...  ...       ...       ...       ...
# 362   23.81164    29.10  4.645107  ...       NaN  3.877178     1.250
# 363   23.76433    28.80  4.616296  ...       NaN  3.840727     0.928
# 364   23.72082    20.40  4.587447  ...       NaN  3.804611     0.897
# 365   23.67850    20.40  4.558578  ...       NaN  3.768979     0.872
# 366   15.50986     9.82  2.810608  ...       NaN  1.775115     0.636
#
#         QOSIM51  QOMEAS52   QOSIM52  QOMEAS53   QOSIM53  QOMEAS54   QOSIM54
# jday
# 1      7.231605     510.0  276.7021      1.83  1.891215     580.0  400.0202
# 2      7.169588     560.0  257.3490      1.80  1.882303     577.0  398.2514
# 3      7.108684     555.0  272.4788      1.91  1.873633     574.0  389.0506
# 4      7.048570     551.0  302.7925      1.82  1.864600     570.0  346.8626
# 5      6.987983     618.0  325.7324      1.81  1.855332     565.0  299.9000
# ...         ...       ...       ...       ...       ...       ...       ...
# 362    9.968048     434.0  390.6223      1.87  1.925934     646.0  396.1742
# 363    9.993054     478.0  391.7387      1.78  1.917466     628.0  398.1071
# 364   10.014960     494.0  388.1187      1.83  1.908819     615.0  400.5276
# 365   10.033870     554.0  385.6168      1.87  1.900035     603.0  400.3325
# 366   10.049890     415.0  347.7978      1.53  0.771303     597.0  368.7908
#
# [366 rows x 108 columns]
# LONG_TERM_MEAN:
#        QOMEAS1    QOSIM1  QOMEAS2    QOSIM2   QOMEAS3    QOSIM3    QOMEAS4  \
# jday
# 1     9.271818  6.270789      NaN  0.670469  0.860563  0.770399  20.554706
# 2     9.371212  6.130119      NaN  0.685355  0.863906  0.766031  19.721765
# 3     9.524242  6.102967      NaN  0.712706  0.845938  0.761210  19.250882
# 4     9.635758  6.095200      NaN  0.729133  0.869437  0.757461  19.249118
# 5     9.645152  6.090865      NaN  0.734895  0.878364  0.754594  18.956765
# ...        ...       ...      ...       ...       ...       ...        ...
# 362   9.441765  6.278464      NaN  0.671997  0.804353  0.767218  21.994857
# 363   9.324706  6.276200      NaN  0.669677  0.833500  0.764986  21.818857
# 364   9.259118  6.273956      NaN  0.667368  0.865794  0.762375  21.394000
# 365   9.264118  6.271767      NaN  0.665061  0.840324  0.759958  21.386000
# 366   7.956667  3.629569      NaN  0.496750  0.780889  0.603452  18.065556
#
#          QOSIM4   QOMEAS5    QOSIM5  ...  QOMEAS50   QOSIM50  QOMEAS51  \
# jday                                 ...
# 1     14.358765  4.766765  2.951173  ...       NaN  0.436905  0.403200
# 2     14.029419  4.810588  2.866589  ...       NaN  0.433229  0.380200
# 3     13.478771  4.759706  2.861968  ...       NaN  0.429515  0.372000
# 4     13.183874  4.628529  2.859579  ...       NaN  0.425773  0.369200
# 5     13.089231  4.562794  2.857200  ...       NaN  0.422045  0.366400
# ...         ...       ...       ...  ...       ...       ...       ...
# 362   14.286114  5.291429  3.054033  ...       NaN  0.490356  0.463500
# 363   14.257295  5.302857  3.049901  ...       NaN  0.486545  0.428750
# 364   14.228988  5.074857  3.045750  ...       NaN  0.482761  0.414187
# 365   14.201132  4.907714  3.041577  ...       NaN  0.479012  0.403687
# 366    9.891890  3.676667  2.761942  ...       NaN  0.331526  0.369250
#
#        QOSIM51    QOMEAS52     QOSIM52  QOMEAS53   QOSIM53    QOMEAS54  \
# jday
# 1     1.243893  270.323529  270.095176  1.168438  0.427756  310.647059
# 2     1.233902  318.470588  253.545965  1.156375  0.425968  309.529412
# 3     1.223990  357.029412  254.373774  1.147063  0.424011  306.911765
# 4     1.214165  388.852941  263.306841  1.147563  0.421989  305.647059
# 5     1.204369  401.176471  281.919768  1.163375  0.419997  307.441176
# ...        ...         ...         ...       ...       ...         ...
# 362   1.532649  272.885714  343.328320  1.185588  0.445678  340.971429
# 363   1.523671  298.685714  342.678777  1.167412  0.443586  331.342857
# 364   1.514604  293.600000  342.074309  1.169176  0.441604  323.514286
# 365   1.505406  296.885714  341.423603  1.134294  0.439722  319.371429
# 366   1.517700  247.777778  335.730700  1.072500  0.393890  319.333333
#
#          QOSIM54
# jday
# 1     348.717059
# 2     348.027821
# 3     344.244432
# 4     317.892359
# 5     282.478321
# ...          ...
# 362   347.814474
# 363   348.803254
# 364   349.352680
# 365   349.594329
# 366   344.544100
#
# [366 rows x 108 columns]
# LONG_TERM_Q33.33:
#       QOMEAS1    QOSIM1  QOMEAS2    QOSIM2  QOMEAS3    QOSIM3  QOMEAS4  \
# jday
# 1      7.1512  7.180255      NaN  0.417562  0.47455  0.578491   14.656
# 2      7.4764  6.858903      NaN  0.429622  0.46230  0.571821   15.068
# 3      7.4520  6.806625      NaN  0.457187  0.46960  0.566352   15.446
# 4      7.4828  6.794676      NaN  0.477641  0.47960  0.562051   15.702
# 5      7.8004  6.789800      NaN  0.486752  0.47692  0.556859   15.712
# ...       ...       ...      ...       ...      ...       ...      ...
# 362    7.5289  7.510383      NaN  0.423294  0.44115  0.549029   15.200
# 363    7.4526  7.510196      NaN  0.422077  0.44725  0.559990   15.222
# 364    7.5613  7.510014      NaN  0.420865  0.45445  0.559052   15.442
# 365    7.5680  7.509835      NaN  0.419657  0.44445  0.546242   15.342
# 366    7.2284  0.452722      NaN  0.420142  0.42872  0.495693   16.136
#
#          QOSIM4  QOMEAS5    QOSIM5  ...  QOMEAS50   QOSIM50  QOMEAS51  \
# jday                                ...
# 1     14.260337   3.3204  2.658963  ...       NaN  0.020178   0.33632
# 2     13.983201   3.1267  2.564091  ...       NaN  0.019576   0.33532
# 3     13.388906   3.2890  2.560963  ...       NaN  0.019126   0.32998
# 4     12.938638   3.2890  2.560775  ...       NaN  0.018694   0.31782
# 5     12.784441   3.2356  2.560623  ...       NaN  0.018280   0.32640
# ...         ...      ...       ...  ...       ...       ...       ...
# 362   14.244395   2.9150  2.760082  ...       NaN  0.023260   0.34080
# 363   14.237042   2.8816  2.759971  ...       NaN  0.022628   0.31975
# 364   14.229738   3.2154  2.759859  ...       NaN  0.022029   0.31455
# 365   14.222449   3.2088  2.759746  ...       NaN  0.021460   0.31400
# 366    6.721796   3.0704  2.749981  ...       NaN  0.020887   0.26012
#
#        QOSIM51  QOMEAS52     QOSIM52  QOMEAS53   QOSIM53  QOMEAS54     QOSIM54
# jday
# 1     0.115181    203.89  268.673074   1.00950  0.216395    261.47  340.443255
# 2     0.114426    250.56  252.904993   0.97190  0.215977    258.92  340.006414
# 3     0.113694    289.56  253.223010   0.95405  0.215542    249.02  337.028638
# 4     0.112985    348.34  254.969906   0.99380  0.215079    235.89  313.496201
# 5     0.112296    347.67  272.063600   0.92955  0.214593    238.78  279.319658
# ...        ...       ...         ...       ...       ...       ...         ...
# 362   0.124263    244.44  332.655566   0.97392  0.221398    288.22  339.755950
# 363   0.122244    232.64  332.682914   0.88112  0.220955    277.42  339.559496
# 364   0.120324    233.44  332.169106   0.91912  0.220511    264.98  340.048226
# 365   0.118494    204.10  332.729052   0.92368  0.220070    261.22  340.748624
# 366   0.236140    182.56  331.047108   0.96921  0.261174    250.28  337.163072
#
# [366 rows x 108 columns]
# LONG_TERM_MEDIAN:
#       QOMEAS1    QOSIM1  QOMEAS2    QOSIM2  QOMEAS3    QOSIM3  QOMEAS4  \
# jday
# 1       8.330  7.330704      NaN  0.596637   0.5965  0.674881    17.70
# 2       8.350  7.046204      NaN  0.613318   0.5835  0.674789    18.00
# 3       8.540  6.996958      NaN  0.643755   0.5910  0.675424    16.90
# 4       8.580  6.986505      NaN  0.661420   0.5960  0.668960    17.90
# 5       8.620  6.981749      NaN  0.667227   0.5670  0.661672    18.35
# ...       ...       ...      ...       ...      ...       ...      ...
# 362     8.260  7.611866      NaN  0.596421   0.5730  0.684061    18.80
# 363     8.265  7.611101      NaN  0.595245   0.5880  0.677179    18.00
# 364     8.285  7.610342      NaN  0.594042   0.5865  0.670399    18.00
# 365     8.260  7.609595      NaN  0.592822   0.6100  0.663721    18.20
# 366     8.100  0.592695      NaN  0.445221   0.5400  0.606157    17.40
#
#          QOSIM4  QOMEAS5    QOSIM5  ...  QOMEAS50   QOSIM50  QOMEAS51  \
# jday                                ...
# 1     14.650735    3.600  2.691447  ...       NaN  0.066722    0.3990
# 2     14.348735    3.950  2.599468  ...       NaN  0.066335    0.3930
# 3     13.797715    4.075  2.596548  ...       NaN  0.065962    0.3770
# 4     13.476980    3.990  2.596405  ...       NaN  0.065601    0.3810
# 5     13.375670    3.925  2.596293  ...       NaN  0.065252    0.3680
# ...         ...      ...       ...  ...       ...       ...       ...
# 362   14.702370    3.660  2.791490  ...       NaN  0.075322    0.3840
# 363   14.693290    3.800  2.791397  ...       NaN  0.074946    0.3965
# 364   14.684260    3.600  2.791296  ...       NaN  0.074579    0.4020
# 365   14.675240    3.800  2.791199  ...       NaN  0.074222    0.4095
# 366    6.939164    3.300  2.758124  ...       NaN  0.136873    0.3340
#
#        QOSIM51  QOMEAS52    QOSIM52  QOMEAS53   QOSIM53  QOMEAS54    QOSIM54
# jday
# 1     0.225986     236.0  270.25070     1.160  0.274803     290.5  350.50410
# 2     0.224289     312.0  253.31445     1.135  0.273843     298.5  348.93990
# 3     0.222622     371.0  253.86870     1.105  0.272904     305.5  344.60980
# 4     0.220984     383.0  260.04965     1.125  0.271986     307.0  317.58385
# 5     0.219375     409.0  281.82865     1.165  0.271097     308.5  280.64810
# ...        ...       ...        ...       ...       ...       ...        ...
# 362   0.280226     282.0  347.29000     1.120  0.279830     345.0  346.63330
# 363   0.277323     300.0  344.85920     1.150  0.279132     309.0  350.10460
# 364   0.274484     272.0  345.56230     1.100  0.278444     295.0  351.52680
# 365   0.271706     260.0  344.10150     1.100  0.277691     294.0  352.02610
# 366   0.372024     197.0  331.41420     0.984  0.467775     287.0  342.15010
#
# [366 rows x 108 columns]
# LONG_TERM_Q75:
#       QOMEAS1    QOSIM1  QOMEAS2    QOSIM2  QOMEAS3    QOSIM3  QOMEAS4  \
# jday
# 1     10.5000  7.620268      NaN  0.735074   1.3000  0.953171    25.70
# 2     10.8000  7.546105      NaN  0.753892   1.2525  0.949297    22.15
# 3     10.8000  7.531412      NaN  0.785092   1.2025  0.944175    20.55
# 4     10.7000  7.525160      NaN  0.801172   1.2525  0.955668    20.80
# 5     10.5000  7.520293      NaN  0.805618   1.3000  0.952074    21.15
# ...       ...       ...      ...       ...      ...       ...      ...
# 362   10.3325  7.733527      NaN  0.740119   1.1875  0.936670    24.35
# 363   10.4750  7.730891      NaN  0.737825   1.2775  0.936056    24.75
# 364   10.4825  7.728257      NaN  0.735543   1.3200  0.936372    25.05
# 365   10.2500  7.725632      NaN  0.733759   1.3275  0.944624    24.70
# 366    8.6100  7.644813      NaN  0.602794   1.0100  0.802964    19.00
#
#          QOSIM4  QOMEAS5    QOSIM5  ...  QOMEAS50   QOSIM50  QOMEAS51  \
# jday                                ...
# 1     17.242480   5.4750  2.973451  ...       NaN  0.458455   0.52500
# 2     16.986160   5.5075  3.029645  ...       NaN  0.456915   0.45650
# 3     16.551932   5.9825  3.022667  ...       NaN  0.455381   0.46050
# 4     16.361275   5.4050  3.014546  ...       NaN  0.453854   0.45050
# 5     16.300290   5.4775  3.006397  ...       NaN  0.452331   0.44150
# ...         ...      ...       ...  ...       ...       ...       ...
# 362   17.434220   5.7000  2.912110  ...       NaN  0.633355   0.47075
# 363   17.373270   6.0600  2.903510  ...       NaN  0.630064   0.47350
# 364   17.312135   6.0000  2.894902  ...       NaN  0.626811   0.49775
# 365   17.249645   5.7500  2.886307  ...       NaN  0.623593   0.46400
# 366   14.818380   4.4000  2.797488  ...       NaN  0.157005   0.46425
#
#        QOSIM51  QOMEAS52     QOSIM52  QOMEAS53   QOSIM53  QOMEAS54     QOSIM54
# jday
# 1     1.061510    328.00  271.914325   1.41250  0.566412    378.75  363.277350
# 2     1.055659    410.00  254.718275   1.40250  0.563642    380.00  361.417875
# 3     1.049869    432.75  254.721375   1.49250  0.560927    374.75  355.776775
# 4     1.043851    451.50  266.973700   1.56500  0.558268    376.75  325.707600
# 5     1.036957    452.00  289.749500   1.60500  0.555370    380.50  286.793500
# ...        ...       ...         ...       ...       ...       ...         ...
# 362   1.362218    312.00  356.011400   1.37000  0.591988    399.50  363.581100
# 363   1.352772    360.00  355.224400   1.44000  0.589158    398.50  364.688500
# 364   1.343460    370.50  354.297150   1.55000  0.586349    395.50  365.495100
# 365   1.334275    380.00  351.631300   1.35000  0.583536    386.50  365.309400
# 366   1.059607    297.00  340.945900   1.13025  0.515479    375.00  350.681000
#
# [366 rows x 108 columns]
# LONG_TERM_Q25:
#       QOMEAS1    QOSIM1  QOMEAS2    QOSIM2  QOMEAS3    QOSIM3  QOMEAS4  \
# jday
# 1       6.800  7.145103      NaN  0.361756  0.39000  0.421872   12.675
# 2       6.850  6.828876      NaN  0.372621  0.40325  0.416742   12.925
# 3       6.870  6.771696      NaN  0.399002  0.39650  0.411744   13.275
# 4       7.000  6.761227      NaN  0.420107  0.38600  0.406861   13.775
# 5       7.460  6.758983      NaN  0.430390  0.39100  0.402081   13.975
# ...       ...       ...      ...       ...      ...       ...      ...
# 362     7.020  7.492788      NaN  0.365907  0.38725  0.398089   13.600
# 363     6.955  7.492751      NaN  0.364860  0.40250  0.393120   14.150
# 364     6.830  7.492713      NaN  0.363815  0.42375  0.388354   13.950
# 365     6.925  7.492681      NaN  0.362774  0.39750  0.383778   13.800
# 366     6.390  0.409838      NaN  0.417568  0.35000  0.325506   14.600
#
#          QOSIM4  QOMEAS5    QOSIM5  ...  QOMEAS50   QOSIM50  QOMEAS51  \
# jday                                ...
# 1     12.727935   2.7725  2.647559  ...       NaN  0.015699   0.30100
# 2     12.523675   3.0000  2.551194  ...       NaN  0.015409   0.30300
# 3     12.112277   2.9675  2.547983  ...       NaN  0.015144   0.30350
# 4     11.790700   3.0925  2.547785  ...       NaN  0.014919   0.30000
# 5     11.669630   3.0750  2.547625  ...       NaN  0.014702   0.31200
# ...         ...      ...       ...  ...       ...       ...       ...
# 362   12.335245   2.7600  2.752887  ...       NaN  0.017363   0.33150
# 363   12.311590   2.7550  2.752732  ...       NaN  0.017025   0.31425
# 364   12.290830   2.8750  2.752577  ...       NaN  0.016700   0.30325
# 365   12.271300   3.0000  2.752421  ...       NaN  0.016388   0.29300
# 366    6.369729   3.0000  2.748298  ...       NaN  0.016260   0.23900
#
#        QOSIM51  QOMEAS52    QOSIM52  QOMEAS53   QOSIM53  QOMEAS54     QOSIM54
# jday
# 1     0.102126    196.75  268.44220   0.98750  0.179660    234.25  332.961825
# 2     0.101000    232.75  252.43815   0.93150  0.179299    232.25  332.969600
# 3     0.099926    269.75  252.48390   0.78650  0.178935    228.50  330.704425
# 4     0.098903    340.25  253.84345   0.68300  0.178569    226.75  309.748725
# 5     0.097926    338.00  268.92820   0.70425  0.178201    229.50  277.721850
# ...        ...       ...        ...       ...       ...       ...         ...
# 362   0.109170    219.50  331.16935   0.89300  0.185658    264.00  333.283200
# 363   0.107974    218.50  331.08255   0.87400  0.185306    247.00  333.247850
# 364   0.106836    212.50  331.33545   0.86800  0.184963    234.50  333.488900
# 365   0.105753    192.50  330.36375   0.82100  0.184627    235.50  333.631550
# 366   0.151124    180.00  330.50810   0.92625  0.233418    233.00  333.299200
#
# [366 rows x 108 columns]
# LONG_TERM_Q33:
#       QOMEAS1    QOSIM1  QOMEAS2    QOSIM2  QOMEAS3    QOSIM3  QOMEAS4  \
# jday
# 1      7.1512  7.180255      NaN  0.417562  0.47455  0.578491   14.656
# 2      7.4764  6.858903      NaN  0.429622  0.46230  0.571821   15.068
# 3      7.4520  6.806625      NaN  0.457187  0.46960  0.566352   15.446
# 4      7.4828  6.794676      NaN  0.477641  0.47960  0.562051   15.702
# 5      7.8004  6.789800      NaN  0.486752  0.47692  0.556859   15.712
# ...       ...       ...      ...       ...      ...       ...      ...
# 362    7.5289  7.510383      NaN  0.423294  0.44115  0.549029   15.200
# 363    7.4526  7.510196      NaN  0.422077  0.44725  0.559990   15.222
# 364    7.5613  7.510014      NaN  0.420865  0.45445  0.559052   15.442
# 365    7.5680  7.509835      NaN  0.419657  0.44445  0.546242   15.342
# 366    7.2284  0.452722      NaN  0.420142  0.42872  0.495693   16.136
#
#          QOSIM4  QOMEAS5    QOSIM5  ...  QOMEAS50   QOSIM50  QOMEAS51  \
# jday                                ...
# 1     14.260337   3.3204  2.658963  ...       NaN  0.020178   0.33632
# 2     13.983201   3.1267  2.564091  ...       NaN  0.019576   0.33532
# 3     13.388906   3.2890  2.560963  ...       NaN  0.019126   0.32998
# 4     12.938638   3.2890  2.560775  ...       NaN  0.018694   0.31782
# 5     12.784441   3.2356  2.560623  ...       NaN  0.018280   0.32640
# ...         ...      ...       ...  ...       ...       ...       ...
# 362   14.244395   2.9150  2.760082  ...       NaN  0.023260   0.34080
# 363   14.237042   2.8816  2.759971  ...       NaN  0.022628   0.31975
# 364   14.229738   3.2154  2.759859  ...       NaN  0.022029   0.31455
# 365   14.222449   3.2088  2.759746  ...       NaN  0.021460   0.31400
# 366    6.721796   3.0704  2.749981  ...       NaN  0.020887   0.26012
#
#        QOSIM51  QOMEAS52     QOSIM52  QOMEAS53   QOSIM53  QOMEAS54     QOSIM54
# jday
# 1     0.115181    203.89  268.673074   1.00950  0.216395    261.47  340.443255
# 2     0.114426    250.56  252.904993   0.97190  0.215977    258.92  340.006414
# 3     0.113694    289.56  253.223010   0.95405  0.215542    249.02  337.028638
# 4     0.112985    348.34  254.969906   0.99380  0.215079    235.89  313.496201
# 5     0.112296    347.67  272.063600   0.92955  0.214593    238.78  279.319658
# ...        ...       ...         ...       ...       ...       ...         ...
# 362   0.124263    244.44  332.655566   0.97392  0.221398    288.22  339.755950
# 363   0.122244    232.64  332.682914   0.88112  0.220955    277.42  339.559496
# 364   0.120324    233.44  332.169106   0.91912  0.220511    264.98  340.048226
# 365   0.118494    204.10  332.729052   0.92368  0.220070    261.22  340.748624
# 366   0.236140    182.56  331.047108   0.96921  0.261174    250.28  337.163072
#
# [366 rows x 108 columns]

# %%
visuals.bounded_plot(
    lines = DATA_2["LONG_TERM_MEDIAN"].iloc[:, [0, 1, 2, 3, 4, 5]],
    upper_bounds = [DATA_2["LONG_TERM_MAX"]],
    lower_bounds = [DATA_2["LONG_TERM_MIN"]],
    # upper_bounds = [DATAFRAMES["LONG_TERM_Q75"]],
    # lower_bounds = [DATAFRAMES["LONG_TERM_Q25"]],
    title='Long Term Aggregation by days of the Year',
    linestyles=['b', 'r-'],
    labels=['Datetime', 'Streamflow'],
    grid=True
    )
